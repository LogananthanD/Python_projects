# %% [markdown]
# <a href="https://colab.research.google.com/github/LogananthanD/Python_projects/blob/main/Ml_Workshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.3/719.3 kB 13.0 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 192MB/s]

# %%
# !touch data.yaml

# %%
model.train(data="/content/data.yaml",epochs =2)
# Out:
# Ultralytics YOLOv8.1.23 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
infer = YOLO("/content/runs/detect/train/weights/best.pt")

# %%
infer.predict("/content/drive/MyDrive/Apple_Dataset/test")
# Out:
# image 1/30 /content/drive/MyDrive/Apple_Dataset/test/apple--1-_jpg.rf.7662faa1233b5fc07d695672f592c04f.jpg: 224x640 (no detections), 79.7ms
# image 2/30 /content/drive/MyDrive/Apple_Dataset/test/apple--10-_jpg.rf.464143fc334f48eea9338640b7e9714a.jpg: 640x480 (no detections), 160.6ms
# image 3/30 /content/drive/MyDrive/Apple_Dataset/test/apple--106-_jpg.rf.11daeb9bfb0c494ff46a33e480047527.jpg: 416x640 (no detections), 135.7ms
# image 4/30 /content/drive/MyDrive/Apple_Dataset/test/apple--11-_jpg.rf.a129f082778939fbd8c6ac070181daca.jpg: 640x640 1 class_2, 212.7ms
# image 5/30 /content/drive/MyDrive/Apple_Dataset/test/apple--111-_jpg.rf.c8049fb0a31bd0c28a954edb1920c526.jpg: 384x640 (no detections), 133.0ms
# image 6/30 /content/drive/MyDrive/Apple_Dataset/test/apple--113-_jpg.rf.badc2d271ca429bd75a9b3213bdd2e6c.jpg: 480x640 (no detections), 152.1ms
# ...
